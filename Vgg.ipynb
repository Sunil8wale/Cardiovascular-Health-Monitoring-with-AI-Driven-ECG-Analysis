# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam, Adagrad, RMSprop, SGD
from torch.autograd import Variable
import torchvision
import pathlib
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt
import pandas as pd

# %%
import torch

# Check if CUDA (GPU) is available and set the device accordingly
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Verify CUDA availability and print GPU name if available
if torch.cuda.is_available():
    print(f"CUDA is available. Device name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available.")
# Out:
# Using device: cuda
# CUDA is available. Device name: Tesla T4

# %%
# Transforms
transformer = transforms.Compose([
    transforms.Resize((224, 224)),  # ResNet50 requires input size (224, 224)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Path for training, validation, and test directories
train_path = '/content/drive/MyDrive/TFR_data/STFT_Data/STFT_train'
val_path = '/content/drive/MyDrive/TFR_data/STFT_Data/STFT_validation'
test_path = '/content/drive/MyDrive/TFR_data/STFT_Data/STFT_test'

# %%
# Counting data samples
train_count = len(glob.glob(os.path.join(train_path, '*/*.png')))
val_count = len(glob.glob(os.path.join(val_path, '*/*.png')))
test_count = len(glob.glob(os.path.join(test_path, '*/*.png')))
print(f"Number of samples in the training set: {train_count}")
print(f"Number of samples in the validation set: {val_count}")
print(f"Number of samples in the test set: {test_count}")
# Out:
# Number of samples in the training set: 800
# Number of samples in the validation set: 100
# Number of samples in the test set: 100

# %%
# Define batch size
batch_size = 32

# %%
# Create datasets and dataloaders for training, validation, and test
train_dataset = torchvision.datasets.ImageFolder(train_path, transform=transformer)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = torchvision.datasets.ImageFolder(val_path, transform=transformer)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataset = torchvision.datasets.ImageFolder(test_path, transform=transformer)

# %%
# Categories
root = pathlib.Path(train_path)
classes = sorted([j.name.split('/')[-1] for j in root.iterdir()])
print(classes)
# Out:
# ['AF_train', 'NSR_train']

# %%
import torch
import torch.nn as nn
import torchvision

# VGG Network
class VGG(nn.Module):
    def __init__(self, num_classes=2):
        super(VGG, self).__init__()
        self.model = torchvision.models.vgg16(pretrained=False)
        # Load the pretrained weights from the local file
        state_dict = torch.load('/content/drive/MyDrive/vgg16-397923af.pth')
        self.model.load_state_dict(state_dict)
        # Change the classifier's last layer to have num_classes output
        self.model.classifier[6] = nn.Linear(4096, num_classes)

    def forward(self, x):
        return self.model(x)

# Load the model
model = VGG(num_classes=2)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# VGG(
#   (model): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#     (classifier): Sequential(
#       (0): Linear(in_features=25088, out_features=4096, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=4096, out_features=4096, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=4096, out_features=2, bias=True)
#     )
#   )
# )

# %%
# Define optimizers (Adam, AdaGrad, RMSprop, SGD)
optimizers = {
    "Adam": Adam(model.parameters(), lr=0.001)
}

criterion = nn.CrossEntropyLoss()

# %%
# Dictionaries for storing losses and accuracies
train_losses = {key: [] for key in optimizers.keys()}
val_losses = {key: [] for key in optimizers.keys()}
train_accuracies = {key: [] for key in optimizers.keys()}
val_accuracies = {key: [] for key in optimizers.keys()}
best_accuracy = {key: 0 for key in optimizers.keys()}

# %%
# Training loop for each optimizer
for opt_name, optimizer in optimizers.items():
    print(f"Training with optimizer: {opt_name}")
    model.train()  # Reset to training mode

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    best_accuracy = 0

    for epoch in range(100):
        running_loss, running_corrects, num_samples = 0.0, 0, 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            running_corrects += torch.sum(preds == labels.data)

            num_samples += labels.size(0)

        epoch_loss = running_loss / num_samples
        epoch_acc = running_corrects.double() / num_samples

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc.item())
# Out:
# Training with optimizer: Adam

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# Assuming the necessary model, device, train_loader, val_loader and other required elements are defined.

# Initialize dictionaries to store the loss and accuracy data
train_losses_dict = {}
train_accuracies_dict = {}
val_losses_dict = {}
val_accuracies_dict = {}

# Training loop for each optimizer
for opt_name, optimizer in optimizers.items():
    print(f"Training with optimizer: {opt_name}")
    model.train()  # Reset to training mode

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []
    best_accuracy[opt_name] = 0  # Initialize best accuracy to 0

    for epoch in range(100):
        running_loss, running_corrects, num_samples = 0.0, 0, 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            running_corrects += torch.sum(preds == labels.data)

            num_samples += labels.size(0)

        epoch_loss = running_loss / num_samples
        epoch_acc = running_corrects.double() / num_samples

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc.item())

        # Validation phase inside the epoch loop
        model.eval()  # Set model to evaluation mode
        val_loss, val_corrects, val_samples = 0.0, 0, 0

        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            with torch.no_grad():
                outputs = model(images)
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data)
                val_loss += loss.item() * images.size(0)
                val_samples += labels.size(0)

        val_loss /= val_samples
        val_losses.append(val_loss)
        val_acc = val_corrects.double() / val_samples
        val_accuracies.append(val_acc.item())

        print(f"Epoch {epoch+1}/5 - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

        # Save model if accuracy improves
        if val_acc > best_accuracy[opt_name]:
            best_accuracy[opt_name] = val_acc
            torch.save(model.state_dict(), f'resnet50_{opt_name}_best_model.pth')

    # Collecting loss and accuracy data in dictionaries for plotting
    train_losses_dict[opt_name] = train_losses
    train_accuracies_dict[opt_name] = train_accuracies
    val_losses_dict[opt_name] = val_losses
    val_accuracies_dict[opt_name] = val_accuracies
# Out:
# Training with optimizer: Adam
# Epoch 1/5 - Train Loss: 0.6972, Train Acc: 0.4725, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 2/5 - Train Loss: 0.6942, Train Acc: 0.4925, Val Loss: 0.6934, Val Acc: 0.5000
# Epoch 3/5 - Train Loss: 0.6958, Train Acc: 0.4800, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 4/5 - Train Loss: 0.6960, Train Acc: 0.4850, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 5/5 - Train Loss: 0.6937, Train Acc: 0.5000, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 6/5 - Train Loss: 0.6941, Train Acc: 0.4875, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 7/5 - Train Loss: 0.6943, Train Acc: 0.4800, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 8/5 - Train Loss: 0.6939, Train Acc: 0.4850, Val Loss: 0.6934, Val Acc: 0.5000
# Epoch 9/5 - Train Loss: 0.6939, Train Acc: 0.4775, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 10/5 - Train Loss: 0.6935, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 11/5 - Train Loss: 0.6935, Train Acc: 0.4650, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 12/5 - Train Loss: 0.6934, Train Acc: 0.4825, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 13/5 - Train Loss: 0.6954, Train Acc: 0.4575, Val Loss: 0.6936, Val Acc: 0.5000
# Epoch 14/5 - Train Loss: 0.6941, Train Acc: 0.5025, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 15/5 - Train Loss: 0.6940, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 16/5 - Train Loss: 0.6936, Train Acc: 0.4800, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 17/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 18/5 - Train Loss: 0.6941, Train Acc: 0.4550, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 19/5 - Train Loss: 0.6940, Train Acc: 0.4725, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 20/5 - Train Loss: 0.6936, Train Acc: 0.4825, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 21/5 - Train Loss: 0.6936, Train Acc: 0.4925, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 22/5 - Train Loss: 0.6936, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 23/5 - Train Loss: 0.6946, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 24/5 - Train Loss: 0.6935, Train Acc: 0.4750, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 25/5 - Train Loss: 0.6938, Train Acc: 0.4900, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 26/5 - Train Loss: 0.6937, Train Acc: 0.4850, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 27/5 - Train Loss: 0.6939, Train Acc: 0.4850, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 28/5 - Train Loss: 0.6938, Train Acc: 0.4975, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 29/5 - Train Loss: 0.6934, Train Acc: 0.4925, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 30/5 - Train Loss: 0.6934, Train Acc: 0.4925, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 31/5 - Train Loss: 0.6939, Train Acc: 0.4775, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 32/5 - Train Loss: 0.6939, Train Acc: 0.4900, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 33/5 - Train Loss: 0.6935, Train Acc: 0.4925, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 34/5 - Train Loss: 0.6949, Train Acc: 0.5000, Val Loss: 0.6937, Val Acc: 0.5000
# Epoch 35/5 - Train Loss: 0.6941, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 36/5 - Train Loss: 0.6937, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 37/5 - Train Loss: 0.6936, Train Acc: 0.5025, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 38/5 - Train Loss: 0.6942, Train Acc: 0.5000, Val Loss: 0.6934, Val Acc: 0.5000
# Epoch 39/5 - Train Loss: 0.6931, Train Acc: 0.5050, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 40/5 - Train Loss: 0.6937, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 41/5 - Train Loss: 0.6936, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 42/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 43/5 - Train Loss: 0.6939, Train Acc: 0.4775, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 44/5 - Train Loss: 0.6935, Train Acc: 0.4775, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 45/5 - Train Loss: 0.6937, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 46/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 47/5 - Train Loss: 0.6936, Train Acc: 0.4825, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 48/5 - Train Loss: 0.6934, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 49/5 - Train Loss: 0.6937, Train Acc: 0.4925, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 50/5 - Train Loss: 0.6939, Train Acc: 0.4725, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 51/5 - Train Loss: 0.6939, Train Acc: 0.4825, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 52/5 - Train Loss: 0.6934, Train Acc: 0.4750, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 53/5 - Train Loss: 0.6937, Train Acc: 0.4725, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 54/5 - Train Loss: 0.6934, Train Acc: 0.4675, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 55/5 - Train Loss: 0.6940, Train Acc: 0.4925, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 56/5 - Train Loss: 0.6935, Train Acc: 0.4725, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 57/5 - Train Loss: 0.6937, Train Acc: 0.4725, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 58/5 - Train Loss: 0.6940, Train Acc: 0.4825, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 59/5 - Train Loss: 0.6939, Train Acc: 0.4950, Val Loss: 0.6934, Val Acc: 0.5000
# Epoch 60/5 - Train Loss: 0.6950, Train Acc: 0.4675, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 61/5 - Train Loss: 0.6940, Train Acc: 0.4875, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 62/5 - Train Loss: 0.6943, Train Acc: 0.5000, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 63/5 - Train Loss: 0.6934, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 64/5 - Train Loss: 0.6942, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 65/5 - Train Loss: 0.6937, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 66/5 - Train Loss: 0.6944, Train Acc: 0.4550, Val Loss: 0.6934, Val Acc: 0.5000
# Epoch 67/5 - Train Loss: 0.6937, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 68/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 69/5 - Train Loss: 0.6935, Train Acc: 0.4875, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 70/5 - Train Loss: 0.6934, Train Acc: 0.4675, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 71/5 - Train Loss: 0.6939, Train Acc: 0.4500, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 72/5 - Train Loss: 0.6931, Train Acc: 0.5025, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 73/5 - Train Loss: 0.6938, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 74/5 - Train Loss: 0.6938, Train Acc: 0.4650, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 75/5 - Train Loss: 0.6948, Train Acc: 0.4800, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 76/5 - Train Loss: 0.6938, Train Acc: 0.4900, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 77/5 - Train Loss: 0.6937, Train Acc: 0.4825, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 78/5 - Train Loss: 0.6937, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 79/5 - Train Loss: 0.6935, Train Acc: 0.4900, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 80/5 - Train Loss: 0.6935, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 81/5 - Train Loss: 0.6933, Train Acc: 0.5025, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 82/5 - Train Loss: 0.6935, Train Acc: 0.4475, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 83/5 - Train Loss: 0.6942, Train Acc: 0.5025, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 84/5 - Train Loss: 0.6936, Train Acc: 0.4900, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 85/5 - Train Loss: 0.6933, Train Acc: 0.5000, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 86/5 - Train Loss: 0.6933, Train Acc: 0.4950, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 87/5 - Train Loss: 0.6933, Train Acc: 0.4750, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 88/5 - Train Loss: 0.6934, Train Acc: 0.4850, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 89/5 - Train Loss: 0.6937, Train Acc: 0.4950, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 90/5 - Train Loss: 0.6936, Train Acc: 0.4800, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 91/5 - Train Loss: 0.6933, Train Acc: 0.5000, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 92/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6933, Val Acc: 0.5000
# Epoch 93/5 - Train Loss: 0.6934, Train Acc: 0.4950, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 94/5 - Train Loss: 0.6935, Train Acc: 0.4775, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 95/5 - Train Loss: 0.6935, Train Acc: 0.5000, Val Loss: 0.6931, Val Acc: 0.5000
# Epoch 96/5 - Train Loss: 0.6937, Train Acc: 0.4875, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 97/5 - Train Loss: 0.6938, Train Acc: 0.4625, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 98/5 - Train Loss: 0.6933, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 99/5 - Train Loss: 0.6936, Train Acc: 0.5000, Val Loss: 0.6932, Val Acc: 0.5000
# Epoch 100/5 - Train Loss: 0.6937, Train Acc: 0.4575, Val Loss: 0.6932, Val Acc: 0.5000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming train_losses_dict, train_accuracies_dict, val_accuracies_dict, and val_losses_dict are dictionaries containing the data

# Plot and save training loss
plt.figure(figsize=(10, 6))
for opt_name, losses in train_losses_dict.items():
    plt.plot(range(1, 101), losses, label=f'{opt_name} Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss by Epoch for Adam Optimizer')
plt.legend()
plt.grid(True)
plt.savefig('training_loss.jpg')  # Save the figure as JPEG

# Save training loss data to CSV
train_losses_df = pd.DataFrame(train_losses_dict)
train_losses_df.to_csv('training_loss_data.csv', index_label='Epoch')

plt.show()

# Plot and save training accuracy
plt.figure(figsize=(10, 6))
for opt_name, accuracies in train_accuracies_dict.items():
    plt.plot(range(1, 101), accuracies, label=f'{opt_name} Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy by Epoch for Adam Optimizer')
plt.legend()
plt.grid(True)
plt.savefig('training_accuracy.jpg')  # Save the figure as JPEG

# Save training accuracy data to CSV
train_accuracies_df = pd.DataFrame(train_accuracies_dict)
train_accuracies_df.to_csv('training_accuracy_data.csv', index_label='Epoch')

plt.show()

# Plot and save validation accuracy
plt.figure(figsize=(10, 6))
for opt_name, accuracies in val_accuracies_dict.items():
    plt.plot(range(1, 101), accuracies, label=f'{opt_name} Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy by Epoch for Adam Optimizer')
plt.legend()
plt.grid(True)
plt.savefig('validation_accuracy.jpg')  # Save the figure as JPEG

# Save validation accuracy data to CSV
val_accuracies_df = pd.DataFrame(val_accuracies_dict)
val_accuracies_df.to_csv('validation_accuracy_data.csv', index_label='Epoch')

plt.show()

# Plot and save validation loss
plt.figure(figsize=(10, 6))
for opt_name, losses in val_losses_dict.items():
    plt.plot(range(1, 101), losses, label=f'{opt_name} Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss by Epoch for Adam Optimizer')
plt.legend()
plt.grid(True)
plt.savefig('validation_loss.jpg')  # Save the figure as JPEG

# Save validation loss data to CSV
val_losses_df = pd.DataFrame(val_losses_dict)
val_losses_df.to_csv('validation_loss_data.csv', index_label='Epoch')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming train_losses_dict, train_accuracies_dict, val_accuracies_dict, and val_losses_dict are dictionaries containing the data

# Define a function to plot data for each optimizer and save the plots as JPEG
def plot_metrics(optimizer_name, train_data, val_data, metric_name, ylabel):
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, 101), train_data[optimizer_name], label=f'Train {metric_name}')
    plt.plot(range(1, 101), val_data[optimizer_name], label=f'Validation {metric_name}')
    plt.title(f'{metric_name} for {optimizer_name} across Epochs')
    plt.xlabel('Epochs')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{optimizer_name}_{metric_name.lower()}_plot.jpg')  # Save the figure as JPEG
    plt.show()

    # Save the data to CSV
    metrics_df = pd.DataFrame({
        'Epoch': range(1, 101),
        f'Train {metric_name}': train_data[optimizer_name],
        f'Validation {metric_name}': val_data[optimizer_name]
    })
    metrics_df.to_csv(f'{optimizer_name}_{metric_name.lower()}_data.csv', index=False)

# Loop through each optimizer to generate separate plots for each metric
for opt_name in optimizers.keys():
    plot_metrics(opt_name, train_losses_dict, val_losses_dict, 'Loss', 'Loss')
    plot_metrics(opt_name, train_accuracies_dict, val_accuracies_dict, 'Accuracy', 'Accuracy')

# %%
import os
import torch
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# Assuming transformer and batch_size are defined
test_path = '/content/drive/MyDrive/TFR_data/STFT_Data/STFT_test'

# Load the test dataset
test_dataset = ImageFolder(test_path, transform=transformer)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Load the trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Check if GPU is available
model = VGG(num_classes=2).to(device)  # Move model to the correct device
model.load_state_dict(torch.load('/content/drive/MyDrive/vgg_Adam_best_model.pth', map_location=device))
model.eval()

# Initialize lists to store predictions
image_ids = [os.path.basename(path) for path, _ in test_dataset.imgs]  # Extract file paths
true_labels = []
predicted_labels = []

# Iterate through the test dataset and make predictions
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)  # Move input data to the correct device
        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        # Store predictions
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(preds.cpu().numpy())

# Print predictions for image ID, true labels, and predicted labels
print("Image ID\tTrue Label\tPredicted Label")
for i in range(len(image_ids)):
    print(f"{image_ids[i]}\t{true_labels[i]}\t{predicted_labels[i]}")

# Save predictions as a CSV file
predictions_data = {'Image ID': image_ids, 'True Label': true_labels, 'Predicted Label': predicted_labels}
predictions_df = pd.DataFrame(predictions_data)
predictions_df.to_csv('predictions.csv', index=False)

print("Predictions saved as predictions.csv")
# Out:
# Image ID	True Label	Predicted Label
# ecg_stft_image_JS01438_I.png	0	1
# ecg_stft_image_JS01545_I.png	0	1
# ecg_stft_image_JS01595_I.png	0	1
# ecg_stft_image_JS01613_I.png	0	1
# ecg_stft_image_JS01639_I.png	0	1
# ecg_stft_image_JS01680_I.png	0	1
# ecg_stft_image_JS01681_I.png	0	1
# ecg_stft_image_JS01687_I.png	0	1
# ecg_stft_image_JS01726_I.png	0	1
# ecg_stft_image_JS01751_I.png	0	1
# ecg_stft_image_JS01757_I.png	0	1
# ecg_stft_image_JS01758_I.png	0	1
# ecg_stft_image_JS01840_I.png	0	1
# ecg_stft_image_JS01854_I.png	0	1
# ecg_stft_image_JS01868_I.png	0	1
# ecg_stft_image_JS01875_I.png	0	1
# ecg_stft_image_JS01937_I.png	0	1
# ecg_stft_image_JS02016_I.png	0	1
# ecg_stft_image_JS02032_I.png	0	1
# ecg_stft_image_JS02042_I.png	0	1
# ecg_stft_image_JS02047_I.png	0	1
# ecg_stft_image_JS02059_I.png	0	1
# ecg_stft_image_JS02063_I.png	0	1
# ecg_stft_image_JS02107_I.png	0	1
# ecg_stft_image_JS02169_I.png	0	1
# ecg_stft_image_JS02301_I.png	0	1
# ecg_stft_image_JS02318_I.png	0	1
# ecg_stft_image_JS02357_I.png	0	1
# ecg_stft_image_JS02378_I.png	0	1
# ecg_stft_image_JS02381_I.png	0	1
# ecg_stft_image_JS02402_I.png	0	1
# ecg_stft_image_JS02405_I.png	0	1
# ecg_stft_image_JS02471_I.png	0	1
# ecg_stft_image_JS02489_I.png	0	1
# ecg_stft_image_JS02508_I.png	0	1
# ecg_stft_image_JS02549_I.png	0	1
# ecg_stft_image_JS02582_I.png	0	1
# ecg_stft_image_JS02614_I.png	0	1
# ecg_stft_image_JS02734_I.png	0	1
# ecg_stft_image_JS02735_I.png	0	1
# ecg_stft_image_JS02813_I.png	0	1
# ecg_stft_image_JS02818_I.png	0	1
# ecg_stft_image_JS02846_I.png	0	1
# ecg_stft_image_JS02866_I.png	0	1
# ecg_stft_image_JS02879_I.png	0	1
# ecg_stft_image_JS02894_I.png	0	1
# ecg_stft_image_JS02909_I.png	0	1
# ecg_stft_image_JS02930_I.png	0	1
# ecg_stft_image_JS02937_I.png	0	1
# ecg_stft_image_JS02941_I.png	0	1
# ecg_stft_image_JS02323_I.png	1	1
# ecg_stft_image_JS02331_I.png	1	1
# ecg_stft_image_JS02343_I.png	1	1
# ecg_stft_image_JS02360_I.png	1	1
# ecg_stft_image_JS02366_I.png	1	1
# ecg_stft_image_JS02367_I.png	1	1
# ecg_stft_image_JS02376_I.png	1	1
# ecg_stft_image_JS02377_I.png	1	1
# ecg_stft_image_JS02383_I.png	1	1
# ecg_stft_image_JS02413_I.png	1	1
# ecg_stft_image_JS02417_I.png	1	1
# ecg_stft_image_JS02502_I.png	1	1
# ecg_stft_image_JS02523_I.png	1	1
# ecg_stft_image_JS02529_I.png	1	1
# ecg_stft_image_JS02538_I.png	1	1
# ecg_stft_image_JS02547_I.png	1	1
# ecg_stft_image_JS02563_I.png	1	1
# ecg_stft_image_JS02593_I.png	1	1
# ecg_stft_image_JS02598_I.png	1	1
# ecg_stft_image_JS02600_I.png	1	1
# ecg_stft_image_JS02618_I.png	1	1
# ecg_stft_image_JS02661_I.png	1	1
# ecg_stft_image_JS02716_I.png	1	1
# ecg_stft_image_JS02774_I.png	1	1
# ecg_stft_image_JS02806_I.png	1	1
# ecg_stft_image_JS02849_I.png	1	1
# ecg_stft_image_JS02867_I.png	1	1
# ecg_stft_image_JS02872_I.png	1	1
# ecg_stft_image_JS02884_I.png	1	1
# ecg_stft_image_JS02911_I.png	1	1
# ecg_stft_image_JS02935_I.png	1	1
# ecg_stft_image_JS02936_I.png	1	1
# ecg_stft_image_JS02948_I.png	1	1
# ecg_stft_image_JS02950_I.png	1	1
# ecg_stft_image_JS02969_I.png	1	1
# ecg_stft_image_JS02974_I.png	1	1
# ecg_stft_image_JS03068_I.png	1	1
# ecg_stft_image_JS03109_I.png	1	1
# ecg_stft_image_JS03137_I.png	1	1
# ecg_stft_image_JS03163_I.png	1	1
# ecg_stft_image_JS03174_I.png	1	1
# ecg_stft_image_JS03194_I.png	1	1
# ecg_stft_image_JS03204_I.png	1	1
# ecg_stft_image_JS03227_I.png	1	1
# ecg_stft_image_JS03257_I.png	1	1
# ecg_stft_image_JS03337_I.png	1	1
# ecg_stft_image_JS03338_I.png	1	1
# ecg_stft_image_JS03459_I.png	1	1
# ecg_stft_image_JS03494_I.png	1	1
# ecg_stft_image_JS03556_I.png	1	1
# Predictions saved as predictions.csv

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Calculate overall test accuracy
test_accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Calculate sensitivity (recall) and specificity
true_negatives, false_positives, false_negatives, true_positives = conf_matrix.ravel()
sensitivity = recall_score(true_labels, predicted_labels)
specificity = true_negatives / (true_negatives + false_positives)

# Calculate F1-score
f1 = f1_score(true_labels, predicted_labels)

# Plot ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print results
print("Overall Test Accuracy:", test_accuracy)
print("Confusion Matrix:")
print(conf_matrix)
print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
print("F1-score:", f1)
# Out:
# Overall Test Accuracy: 0.5
# Confusion Matrix:
# [[ 0 50]
#  [ 0 50]]
# Sensitivity (Recall): 1.0
# Specificity: 0.0
# F1-score: 0.6666666666666666
